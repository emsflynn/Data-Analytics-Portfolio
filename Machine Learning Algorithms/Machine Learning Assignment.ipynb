# %%
#Machine Learning Assingment

# %%
import numpy as np
import pandas as pd

# %%
inPath = '/Users/emsfl/Downloads/'
inpDf = pd.read_csv(inPath + 'HR_DB.csv', sep=',', header=0, index_col=None)

# %%
inpDf
# Out:
#        satisfactLvl  previousEval  projectQty  avgMtlyHrs  timeAtCie  \
# 0              0.38          0.53         2.0       157.0        3.0
# 1              0.80          0.86         5.0       262.0        6.0
# 2              0.11          0.88         7.0       272.0        4.0
# 3              0.72          0.87         5.0       223.0        5.0
# 4              0.37          0.52         2.0       159.0        3.0
# ...             ...           ...         ...         ...        ...
# 14994          0.40          0.57         2.0       151.0        3.0
# 14995          0.37          0.48         2.0       160.0        3.0
# 14996          0.37          0.53         2.0       143.0        3.0
# 14997          0.11          0.96         6.0       280.0        4.0
# 14998          0.37          0.52         2.0       158.0        3.0
#
#        workAccident  recentPromotion division    wage  resigned
# 0               0.0                0    sales     low         1
# 1               0.0                0    sales  medium         1
# 2               0.0                0    sales  medium         1
# 3               0.0                0    sales     low         1
# 4               0.0                0    sales     low         1
# ...             ...              ...      ...     ...       ...
# 14994           0.0                0  support     low         1
# 14995           0.0                0  support     low         1
# 14996           0.0                0  support     low         1
# 14997           0.0                0  support     low         1
# 14998           0.0                0  support     low         1
#
# [14999 rows x 10 columns]

# %%
inpDf.shape
# Out:
# (14999, 10)

# %%
inpDf = inpDf.dropna(axis=0, how='any')

# %%
inpDf
# Out:
#        satisfactLvl  previousEval  projectQty  avgMtlyHrs  timeAtCie  \
# 0              0.38          0.53         2.0       157.0        3.0
# 1              0.80          0.86         5.0       262.0        6.0
# 2              0.11          0.88         7.0       272.0        4.0
# 3              0.72          0.87         5.0       223.0        5.0
# 4              0.37          0.52         2.0       159.0        3.0
# ...             ...           ...         ...         ...        ...
# 14994          0.40          0.57         2.0       151.0        3.0
# 14995          0.37          0.48         2.0       160.0        3.0
# 14996          0.37          0.53         2.0       143.0        3.0
# 14997          0.11          0.96         6.0       280.0        4.0
# 14998          0.37          0.52         2.0       158.0        3.0
#
#        workAccident  recentPromotion division    wage  resigned
# 0               0.0                0    sales     low         1
# 1               0.0                0    sales  medium         1
# 2               0.0                0    sales  medium         1
# 3               0.0                0    sales     low         1
# 4               0.0                0    sales     low         1
# ...             ...              ...      ...     ...       ...
# 14994           0.0                0  support     low         1
# 14995           0.0                0  support     low         1
# 14996           0.0                0  support     low         1
# 14997           0.0                0  support     low         1
# 14998           0.0                0  support     low         1
#
# [14994 rows x 10 columns]

# %%
inpDf = pd.get_dummies(inpDf, columns=['division'], prefix='Dpt')
inpDf
# Out:
#        satisfactLvl  previousEval  projectQty  avgMtlyHrs  timeAtCie  \
# 0              0.38          0.53         2.0       157.0        3.0
# 1              0.80          0.86         5.0       262.0        6.0
# 2              0.11          0.88         7.0       272.0        4.0
# 3              0.72          0.87         5.0       223.0        5.0
# 4              0.37          0.52         2.0       159.0        3.0
# ...             ...           ...         ...         ...        ...
# 14994          0.40          0.57         2.0       151.0        3.0
# 14995          0.37          0.48         2.0       160.0        3.0
# 14996          0.37          0.53         2.0       143.0        3.0
# 14997          0.11          0.96         6.0       280.0        4.0
# 14998          0.37          0.52         2.0       158.0        3.0
#
#        workAccident  recentPromotion    wage  resigned  Dpt_IT  Dpt_RandD  \
# 0               0.0                0     low         1   False      False
# 1               0.0                0  medium         1   False      False
# 2               0.0                0  medium         1   False      False
# 3               0.0                0     low         1   False      False
# 4               0.0                0     low         1   False      False
# ...             ...              ...     ...       ...     ...        ...
# 14994           0.0                0     low         1   False      False
# 14995           0.0                0     low         1   False      False
# 14996           0.0                0     low         1   False      False
# 14997           0.0                0     low         1   False      False
# 14998           0.0                0     low         1   False      False
#
#        Dpt_accounting  Dpt_hr  Dpt_management  Dpt_marketing  Dpt_product_mng  \
# 0               False   False           False          False            False
# 1               False   False           False          False            False
# 2               False   False           False          False            False
# 3               False   False           False          False            False
# 4               False   False           False          False            False
# ...               ...     ...             ...            ...              ...
# 14994           False   False           False          False            False
# 14995           False   False           False          False            False
# 14996           False   False           False          False            False
# 14997           False   False           False          False            False
# 14998           False   False           False          False            False
#
#        Dpt_sales  Dpt_support  Dpt_technical
# 0           True        False          False
# 1           True        False          False
# 2           True        False          False
# 3           True        False          False
# 4           True        False          False
# ...          ...          ...            ...
# 14994      False         True          False
# 14995      False         True          False
# 14996      False         True          False
# 14997      False         True          False
# 14998      False         True          False
#
# [14994 rows x 19 columns]

# %%
#LABEL ENCODING

inpDf['wage'].unique()
wageDict = {'low': 1, 'medium': 2, 'high': 3}
inpDf['wage'] = inpDf['wage'].map(wageDict)

# %%
print(inpDf['recentPromotion'].skew())
print(inpDf['recentPromotion'].kurt())

#If normally distributed : skewness would be between -2 and 2 and kustrosis would be between -7 and 7 

#THERE, IT IS NOT NORMALLY DISTRIBUTED
# Out:
# 6.635788009726694
# 42.03928997394511

# %%
#standardizing variable
inpDf['avgMtlyHrs'] = (inpDf['avgMtlyHrs'] - inpDf['avgMtlyHrs'].mean()) / inpDf['avgMtlyHrs'].std()

# %%
inpDf['avgMtlyHrs']
# Out:
# 0       -0.881861
# 1        1.220658
# 2        1.420898
# 3        0.439723
# 4       -0.841813
#            ...
# 14994   -1.002005
# 14995   -0.821789
# 14996   -1.162197
# 14997    1.581090
# 14998   -0.861837
# Name: avgMtlyHrs, Length: 14994, dtype: float64

# %%
yDf = inpDf['resigned']
xDf = inpDf.drop(columns='resigned')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.3, random_state=0)

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
#set algorithm parameters
clf = svm.SVC(C=100, kernel='rbf', gamma=1, random_state=0)

# %%
#Fit the data
clf.fit(X_train, y_train)
# Out:
# SVC(C=100, gamma=1, random_state=0)

# %%
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9715492331629251

# %%
#Random Forests - used for classification and regression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#set algorithm parameters
for nTree in [2, 10, 50]:
    clf = RandomForestClassifier(n_estimators=nTree, random_state=0)

# %%
#fit data
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
print(f"Number of trees: {nTree}")
print(f"Accuracy: {clf.score(X_test, y_test)}")
print('')
# Out:
# Number of trees: 50
# Accuracy: 0.9895532340520116

# %%
clf = RandomForestClassifier(n_estimators=50, random_state=0)
# Fit the data
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
feature_importances = clf.feature_importances_

# %%
#associate feature names with importance scores
featImpDf = pd.DataFrame({'Feature': xDf.columns, 'Importance': feature_importances})

# %%
featImpDf_Sort = featImpDf.sort_values(by='Importance', ascending=False)

# %%
#these are the 3 most important features
print(featImpDf_Sort.head(3))
# Out:
#         Feature  Importance
# 0  satisfactLvl    0.319298
# 2    projectQty    0.181888
# 4     timeAtCie    0.175435
